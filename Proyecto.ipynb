# %% [markdown]
# <a href="https://colab.research.google.com/github/cinsalazar/handson-ml2/blob/master/Proyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open ('L archivo.txt', 'r') as file:
 #leeArchivo = file.read() 
  # file = open("L archivo.txt'", "r")
   while(True):
     linea = file.readline()
     print(linea)
     if not linea:
       break
   file.close()

# %%
txtArchivo    = []
archivo       = ""
gi            = 0
patron        = ""

#DEFINICIÓN DE FUNCIONES

def sub_archivo(comando):
  with open ('L archivo.txt', 'r') as file:
 #leeArchivo = file.read() 
  # file = open("L archivo.txt'", "r")
   while(True):
     lineas = file.readline()
     txtArchivo  = lineas
     if not lineas:
       break
   file.close()
print(txtArchivo)
pass 

  #  """ Extraer línea por línea el contenido de un archivo y 
     #   concatenarlo en la lista txtArchivo para su edición 
       # Entrada     : comando
       # Salida      : txtArchivo
       # Restriccion : sólo pueden ser archivos .txt
     # Recuerden remover esta instruccion cuando programen la funcion

def guardar():
    """ Guarda las modificaciones realizadas a txtArchivo
        Entrada     : Ninguna
        Salida      : Ninguna
        Restricción : Ninguna
    """
    pass # Recuerden remover esta instruccion cuando programen la funcion

def guardar_como(comando):
    """ Guarda las modificaciones en un nuevo archivo
        Entrada     : comando
        Salida      : Ninguna
        Restricción : Ninguna
    """
    pass # Recuerden remover esta instruccion cuando programen la funcion

def BorraLinea(comando):
    """ Borra una línea específica de txtArchivo
        Entrada     : comando
        Salida      : Ninguna
        Restricción : Ninguna
    """
    pass # Recuerden remover esta instruccion cuando programen la funcion

def I_final():
    """ Insertar línea al final de txtArchivo
        Entrada     : linea
        Salida      : Ninguna
        Restricción : Sólo se puede ingresar una línea a la vez
    """
    pass # Recuerden remover esta instruccion cuando programen la funcion

def I_ind(comando):
    """ Insertar una línea en una pocisión 'n' a txtArchivo
        Entrada     : linea
        Salida      : Ninguna
        Restricción : Sólo se puede ingresar una línea a la vez
    """
    pass # Recuerden remover esta instruccion cuando programen la funcion
  
def Pprint():
    """ Desplegar el contenido de txtArchivo en línea enumeradas
        Entrada     : Ninguna
        Salida      : Ninguna
        Restricción : Ninguna
    """
    pass # Recuerden remover esta instruccion cuando programen la funcion
        
def Bpatron(i, comando):
    """ Buscar la primera instancia patrón en el texto
        Entrada     : i, comando
        Salida      : la línea que contiene el patrón debidamente enumerada
        Restricción : Ninguna
    """
    pass # Recuerden remover esta instruccion cuando programen la funcion
    
def Npatron(comando):
    """ Buscar la primera instancia patrón en el texto
        Entrada     : comando
        Salida      : la siguiente línea que contiene el patrón debidamente enumerada
        Restricción : Ninguna
    """
    pass # Recuerden remover esta instruccion cuando programen la funcion
        
def principal():
    """ Función que evalua cual comando se ejecutará
        Entradas      : comando
        Salidas       : Ninguna
        Restricciones : Ninguna
    """
    print('')

    comando = str(input("--> "))
    while comando:
        ini = comando[0]
        if comando == "AYUDA":
            print(ayuda)
            
        elif comando == "INSTRUCCIONES":
            print(instrucciones)
            
        elif ini == "L":
            sub_archivo(comando)
            
        elif ini == "C":
            txtArchivo.clear()

        elif ini == "S" and len(comando) == 1:
            guardar()
            
        elif ini == "S" and len(comando) > 2:
            guardar_como(comando)
                        
        elif ini == "D":
            BorraLinea(comando)                
        
        elif ini == "I" and len(comando) == 1:
            I_final()          
        
        elif ini == "I" and len(comando) > 2:
            I_ind(comando)
    
        elif ini == "P":
            Pprint()

        elif ini == "F":
            Bpatron(0, comando)
              
        elif ini == "N":
            Npatron(comando)
        
        else:
            print("ERROR DE COMANDO")
        
        comando = str(input("--> "))
    print("Fin de la edición")

    
if __name__ == "__main__":
	principal()

# %%
txtArchivo    = []
archivo       = ""
def sub_archivo(comando):
  with open ('L archivo.txt', 'r') as file:
 #leeArchivo = file.read() 
  # file = open("L archivo.txt'", "r")
   while(True):
     lineas = file.readline()
     if not lineas:
       break
   file.close()
print(txtArchivo)
pass
# Out:
# []
